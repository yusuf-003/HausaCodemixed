# %%
import pandas as pd
# Load your HausaStemmer class or function
from hausastemmer import HausaStemmer
#from HausaStemmer_modified import HausaStemmer

# %% [markdown]
# Word and their respect stem collected from expert for ablation and evaluation study of the HausaStemming Algorithm.

# %%
simple_cases = {'word':['murhu','bane','gado','doki','rubutu','atamfa','littafi','dafi','riga','wando','hula','agogo','karfe','tasa','wuta','takalmi','jaka','tsuntsu','alkalami','takadda','lifafa','rago','gurgu','katsine','kano','gudana','dori','cika','kirga','kwaya','share','girki','takalmi','wanka','dukufa','suma','rame','mallaka','wasika','jarida','gwano','gwanda','gyambo','rauni','kida','rawa','rangwada','tuwo','masara','masarauta','makaranta','hankali','fasata','dangantaka','aukuwa','jarida','kifi','rijiya','wuri','famfo','yanka','ashasha','dambe','gama','riba','kwando','tallafi','haihuwa','damuwa','rabuwa','kaifi','suka','mike','wasu','mutane','kayan','yakin','jikin','malam','suka','fara','dauka','daure','masa','hannu','hada','icen','haifa'],
        'expected_stem_simple':['murh','ban','gad','dok','rubut','atamf','littaf','daf','rig','wand','hul','agog','karf','tas','wut','takalm','jak','tsunts','alkalam','takadd','lifaf','rag','gurg','katsin','kan','gudan','dor','cik','kirg','kway','shar','girk','takalm','wank','dukuf','sum','ram','mallak','wasik','jarid','gwan','gwand','gyamb','raun','kid','raw','rangwad','tuw','masar','masaraut','makarant','hankal','fasat','dangantak','aukuw','jarid','kif','rijiy','wur','famf','yank','ashash','damb','gam','rib','kwand','tallaf','haihuw','damuw','rabuw','kaif','sul','mik','was','mutan','kay','yak','jik','malam','suka','far','dauk','daur','mas','hann','had','ice','haif']}

complex_cases = {'word':['yar-malam','dan-malam','maaikachi','mafauchi','marowachi','matsorachi','namiji','iri-iri','Hainyaiyai','dakunkuna','takardodi','gasussuka','magunguna','sha daya','bara-gurbi','baram-baram','dumu-dumu','filla-filla','likkafanin','ummanta','shekarunsu','lokaci-lokaci','dagargajewa','shuke-shuken','rayuwarta','maganganu','mahaifinta','haramtacciyar','gulmace-gulmacen','tsakaninsu','mummunan','tangamemen','wad"annan','lashe-lashensa','tande-tande','harbe-harben','ta"bara','barazanar','taimakeni'],
                'expected_stem_complex':['yar-malam','dan-malam','aikach','fauch','row','tsorach','namij','iri','hainy','dakunk','takardod','gasussuk','magungun','sha daya','bara-gurb','baram-baram','dumu-dumu','filla-filla','likkafan','umma','shekaruns','lokac','dagargajew','shuk','rayuw','magan','haif','haram','gulm','tsakanins','mummun','tangamemen','wad"an','lash','tande-tande','harb','ta"bara','barazan','taimak']}

#df1 = pd.DataFrame(simple_cases)
df = pd.DataFrame(complex_cases)

# %%
df.head()
# Out:
#         word expected_stem_complex
# 0  yar-malam             yar-malam
# 1  dan-malam             dan-malam
# 2  maaikachi                aikach
# 3   mafauchi                 fauch
# 4  marowachi                   row

# %%
df.to_csv('words_and_stems_complex.csv', index=False)

# %%
# Example: Assuming you have uploaded a CSV file with words and their expected stems
# The CSV should have two columns: 'Word' and 'ExpectedStem'
file_path = 'words_and_stems_complex.csv'  # Update with the actual path to your file

# Load the data
try:
    data = pd.read_csv(file_path)
except FileNotFoundError:
    raise FileNotFoundError(f"File not found at {file_path}. Please ensure the file path is correct.")

# Ensure the necessary columns are in the file
if not {'word', 'expected_stem_complex'}.issubset(data.columns):
    raise ValueError("The CSV file must contain 'word' and 'expected_stem_complex' columns.")

# Initialize your HausaStemmer instance
stemmer = HausaStemmer()

# Add a column for the stemmer output and correctness
data['StemmerOutput'] = data['word'].apply(lambda word: stemmer.stem(word))
data['Correct'] = data['StemmerOutput'] == data['expected_stem_complex']

# Calculate accuracy metrics
total_words = len(data)
correct_stems = data['Correct'].sum()
accuracy = (correct_stems / total_words) * 100

# Display results
print(f"Total Words Evaluated: {total_words}")
print(f"Correctly Stemmed Words: {correct_stems}")
print(f"Accuracy: {accuracy:.2f}%")

# Save the evaluation results to a new CSV file
evaluation_file_path = 'hausastemmer_evaluation_complex_results.csv'
data.to_csv(evaluation_file_path, index=False)
# Out:
# Total Words Evaluated: 39
# Correctly Stemmed Words: 20
# Accuracy: 51.28%

# %%
df2 = pd.read_csv('/content/hausastemmer_evaluation_complex_results.csv')
df2.head()
# Out:
#         word expected_stem_complex StemmerOutput  Correct
# 0  yar-malam             yar-malam        ya lam    False
# 1  dan-malam             dan-malam        da lam    False
# 2  maaikachi                aikach        aikach     True
# 3   mafauchi                 fauch          fauc    False
# 4  marowachi                   row           row     True

# %%
df2['Correct'].value_counts()
# Out:
# Correct
# True     20
# False    19
# Name: count, dtype: int64

# %%
df2[df2['Correct']==False]
# Out:
#                 word expected_stem_complex    StemmerOutput  Correct
# 0          yar-malam             yar-malam           ya lam    False
# 1          dan-malam             dan-malam           da lam    False
# 3           mafauchi                 fauch             fauc    False
# 7            iri-iri                   iri            ir ir    False
# 10         takardodi              takardod             kard    False
# 13          sha daya              sha daya           sh day    False
# 14        bara-gurbi             bara-gurb             gurb    False
# 15       baram-baram           baram-baram          ram ram    False
# 16         dumu-dumu             dumu-dumu          dum dum    False
# 17       filla-filla           filla-filla        fill fill    False
# 21     lokaci-lokaci                 lokac        loka loka    False
# 23      shuke-shuken                  shuk        shu shuke    False
# 26        mahaifinta                  haif            haifi    False
# ...

# %%
sample_text = "Jiya da na je gida sai naga gidaje kusan dari uku akusa da gidajen sarkin Kano. Abin mamaki shine gidajensu Malam Sabitu ma ashe suna, kusa da gidan sarkin da aka gina gidanka dab da gidansa harda gidansu."

# %%
stemmed_text = stemmer.stem(sample_text)
print("Input Text:\n", sample_text, "\n")
print("Stemmed Text:\n", stemmed_text)
# Out:
# Input Text:
#  Jiya da na je gida sai naga gidaje kusan dari uku akusa da gidajen sarkin Kano. Abin mamaki shine gidajensu Malam Sabitu ma ashe suna, kusa da gidan sarkin da aka gina gidanka dab da gidansa harda gidansu.
#
# Stemmed Text:
#  Jiy je gid nag gidaj kusa dar uku akus gidaj sark Kano Ab ma shine gidaj malam Sabit ashe ku gid sark aka gidan dab gidan hard gidan
